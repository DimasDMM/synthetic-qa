# %% [markdown]
# # Group evaluations
#
# Once we have produced several `xx_metrics.json` files, this notebook will put all together in a single CSV file.

# %%
import glob
import json
import os
import pandas as pd
import re

# %%
def group_metrics(ckpt_names):
    df = {
        'ckpt_names': [],
        'dataset_names': [],
        'exact_scores': [],
        'f1_scores': [],
    }
    
    for ckpt_name in ckpt_names:
        input_path = '../artifacts/predictions_normal/%s/' % ckpt_name
        
        files = glob.glob('%s*_metrics.json' % input_path)
        for file in files:
            filename = os.path.basename(file)
            dataset_name = re.sub(r'_metrics.json', '', filename)
            with open(file, 'r') as fp:
                scores = json.load(fp)

            df['ckpt_names'].append(ckpt_name)
            df['dataset_names'].append(dataset_name)
            df['exact_scores'].append(scores['exact'])
            df['f1_scores'].append(scores['f1'])

    df = pd.DataFrame.from_dict(df).set_index('ckpt_names')
    return df

# %%
ckpt_names = ['qa_mbert_squad', 'qa_mbert_squad5k']
group_metrics(ckpt_names)
# Out:
#                                   dataset_names  exact_scores  f1_scores
# ckpt_names
# qa_mbert_squad                      dev-v1.1-es     49.995226  68.698912
# qa_mbert_squad                      dev-v1.1-ja     61.514196  63.412198
# qa_mbert_squad                         dev-v1.1     80.982296  88.106862
# qa_mbert_squad               mlqa-v1-test-es-es     42.368320  62.849735
# qa_mbert_squad               mlqa-v1-test-hi-hi     31.982314  45.998602
# qa_mbert_squad               mlqa-v1-test-vi-vi     39.633639  58.526424
# qa_mbert_squad     tydiqa-gold-v1.1-dev-russian     47.044025  64.788938
# qa_mbert_squad    tydiqa-goldp-v1.1-dev-russian     47.044025  64.788938
# qa_mbert_squad                         xquad.es     55.089820  73.298553
# qa_mbert_squad                         xquad.hi     41.261261  54.933071
# qa_mbert_squad                         xquad.ru     51.523064  68.753448
# qa_mbert_squad                         xquad.vi     48.458904  67.280343
# qa_mbert_squad5k                    dev-v1.1-es     41.363506  58.823985
# qa_mbert_squad5k                    dev-v1.1-ja     47.318612  49.575988
# qa_mbert_squad5k                       dev-v1.1     66.914144  76.651540
# qa_mbert_squad5k             mlqa-v1-test-es-es     32.449058  50.574847
# qa_mbert_squad5k             mlqa-v1-test-hi-hi     23.335790  36.398239
# qa_mbert_squad5k             mlqa-v1-test-vi-vi     28.892590  45.750764
# qa_mbert_squad5k   tydiqa-gold-v1.1-dev-russian     38.742138  55.672610
# qa_mbert_squad5k  tydiqa-goldp-v1.1-dev-russian     38.742138  55.672610
# qa_mbert_squad5k                       xquad.es     42.600513  59.880519
# qa_mbert_squad5k                       xquad.hi     30.270270  43.203303
# qa_mbert_squad5k                       xquad.ru     39.512620  56.282391
# qa_mbert_squad5k                       xquad.vi     36.729452  53.409270

# %%
ckpt_names = ['qa_xlm_squad', 'qa_xlm_squad5k']
group_metrics(ckpt_names)
# Out:
#                                 dataset_names  exact_scores  f1_scores
# ckpt_names
# qa_xlm_squad                      dev-v1.1-es     45.292037  61.447115
# qa_xlm_squad                      dev-v1.1-ja     53.822630  55.142096
# qa_xlm_squad                         dev-v1.1     69.661421  75.559731
# qa_xlm_squad               mlqa-v1-test-es-es     36.115385  53.578392
# qa_xlm_squad               mlqa-v1-test-hi-hi     33.799955  47.808495
# qa_xlm_squad               mlqa-v1-test-vi-vi     38.632585  55.235670
# qa_xlm_squad     tydiqa-gold-v1.1-dev-russian     31.203008  46.337288
# qa_xlm_squad    tydiqa-goldp-v1.1-dev-russian     31.203008  46.337288
# qa_xlm_squad                         xquad.es     49.786142  64.441313
# qa_xlm_squad                         xquad.hi     43.793103  56.515629
# qa_xlm_squad                         xquad.ru     48.058671  62.587130
# qa_xlm_squad                         xquad.vi     45.633562  62.444551
# qa_xlm_squad5k                    dev-v1.1-es     38.915974  55.542811
# qa_xlm_squad5k                    dev-v1.1-ja     46.788991  48.230522
# qa_xlm_squad5k                       dev-v1.1     60.410110  69.706916
# qa_xlm_squad5k             mlqa-v1-test-es-es     29.461538  46.942771
# qa_xlm_squad5k             mlqa-v1-test-hi-hi     22.578460  35.253760
# qa_xlm_squad5k             mlqa-v1-test-vi-vi     28.491272  44.429245
# qa_xlm_squad5k   tydiqa-gold-v1.1-dev-russian     28.947368  45.119448
# qa_xlm_squad5k  tydiqa-goldp-v1.1-dev-russian     28.947368  45.119448
# qa_xlm_squad5k                       xquad.es     42.087254  57.829440
# qa_xlm_squad5k                       xquad.hi     33.879310  47.271469
# qa_xlm_squad5k                       xquad.ru     38.567731  54.654736
# qa_xlm_squad5k                       xquad.vi     39.811644  55.416336

# %%
ckpt_names = ['qa_mbert_synthetic_es_top1', 'qa_mbert_synthetic_es_top2',
              'qa_mbert_synthetic_es_top3', 'qa_mbert_synthetic_es_top5',
              'qa_mbert_extsquad_es_top1', 'qa_mbert_extsquad_es_top2',
              'qa_mbert_extsquad_es_top3', 'qa_mbert_extsquad_es_top5',
              'qa_mbert_extsquad5k_es_top1', 'qa_mbert_extsquad5k_es_top2',
              'qa_mbert_extsquad5k_es_top3', 'qa_mbert_extsquad5k_es_top5']
group_metrics(ckpt_names)
# Out:
#                                   dataset_names  exact_scores  f1_scores
# ckpt_names
# qa_mbert_synthetic_es_top1          dev-v1.1-es     14.742672  21.796018
# qa_mbert_synthetic_es_top1   mlqa-v1-test-es-es     12.360631  20.613115
# qa_mbert_synthetic_es_top1             xquad.es     14.371257  22.040813
# qa_mbert_synthetic_es_top2          dev-v1.1-es     16.490022  23.993730
# qa_mbert_synthetic_es_top2   mlqa-v1-test-es-es     13.264129  21.811303
# qa_mbert_synthetic_es_top2             xquad.es     15.911035  23.092772
# qa_mbert_synthetic_es_top3          dev-v1.1-es     18.886661  27.726908
# qa_mbert_synthetic_es_top3   mlqa-v1-test-es-es     15.186467  25.984014
# qa_mbert_synthetic_es_top3             xquad.es     17.365269  27.308467
# qa_mbert_synthetic_es_top5          dev-v1.1-es     17.693116  25.406085
# qa_mbert_synthetic_es_top5   mlqa-v1-test-es-es     14.321415  24.475166
# qa_mbert_synthetic_es_top5             xquad.es     16.167665  24.316342
# qa_mbert_extsquad_es_top1           dev-v1.1-es     49.670581  65.814944
# qa_mbert_extsquad_es_top1    mlqa-v1-test-es-es     40.580546  60.025211
# qa_mbert_extsquad_es_top1              xquad.es     53.550043  69.484567
# qa_mbert_extsquad_es_top2           dev-v1.1-es     49.804259  65.531713
# qa_mbert_extsquad_es_top2    mlqa-v1-test-es-es     39.004229  58.385423
# qa_mbert_extsquad_es_top2              xquad.es     52.951240  69.446082
# qa_mbert_extsquad_es_top3           dev-v1.1-es     49.059486  64.863400
# qa_mbert_extsquad_es_top3    mlqa-v1-test-es-es     37.985390  57.341520
# qa_mbert_extsquad_es_top3              xquad.es     50.898204  67.052686
# qa_mbert_extsquad_es_top5           dev-v1.1-es     48.028263  63.702557
# qa_mbert_extsquad_es_top5    mlqa-v1-test-es-es     38.043060  57.377052
# qa_mbert_extsquad_es_top5              xquad.es     51.325920  67.004072
# qa_mbert_extsquad5k_es_top1         dev-v1.1-es     40.456412  55.677674
# qa_mbert_extsquad5k_es_top1  mlqa-v1-test-es-es     30.296040  47.426347
# qa_mbert_extsquad5k_es_top1            xquad.es     40.804106  56.914702
# qa_mbert_extsquad5k_es_top2         dev-v1.1-es     38.308030  53.164145
# qa_mbert_extsquad5k_es_top2  mlqa-v1-test-es-es     28.604383  44.866591
# qa_mbert_extsquad5k_es_top2            xquad.es     38.579983  53.838133
# qa_mbert_extsquad5k_es_top3         dev-v1.1-es     38.336675  53.556750
# qa_mbert_extsquad5k_es_top3  mlqa-v1-test-es-es     28.777393  45.513425
# qa_mbert_extsquad5k_es_top3            xquad.es     36.270317  53.268819
# qa_mbert_extsquad5k_es_top5         dev-v1.1-es     38.537191  53.175704
# qa_mbert_extsquad5k_es_top5  mlqa-v1-test-es-es     29.546328  45.759372
# qa_mbert_extsquad5k_es_top5            xquad.es     38.237810  54.116995

# %%
ckpt_names = ['qa_mbert_synthetic_ru_top1', 'qa_mbert_synthetic_ru_top2',
              'qa_mbert_synthetic_ru_top3', 'qa_mbert_synthetic_ru_top5',
              'qa_mbert_extsquad_ru_top1', 'qa_mbert_extsquad_ru_top2',
              'qa_mbert_extsquad_ru_top3', 'qa_mbert_extsquad_ru_top5',
              'qa_mbert_extsquad5k_ru_top1', 'qa_mbert_extsquad5k_ru_top2',
              'qa_mbert_extsquad5k_ru_top3', 'qa_mbert_extsquad5k_ru_top5']
group_metrics(ckpt_names)
# Out:
#                                              dataset_names  exact_scores  \
# ckpt_names
# qa_mbert_synthetic_ru_top1   tydiqa-goldp-v1.1-dev-russian     15.723270
# qa_mbert_synthetic_ru_top1                        xquad.ru     12.619669
# qa_mbert_synthetic_ru_top2   tydiqa-goldp-v1.1-dev-russian     16.981132
# qa_mbert_synthetic_ru_top2                        xquad.ru     14.708442
# qa_mbert_synthetic_ru_top3   tydiqa-goldp-v1.1-dev-russian     16.855346
# qa_mbert_synthetic_ru_top3                        xquad.ru     15.143603
# qa_mbert_synthetic_ru_top5   tydiqa-goldp-v1.1-dev-russian     18.113208
# qa_mbert_synthetic_ru_top5                        xquad.ru     14.447346
# qa_mbert_extsquad_ru_top1    tydiqa-goldp-v1.1-dev-russian     47.169811
# qa_mbert_extsquad_ru_top1                         xquad.ru     49.260226
# qa_mbert_extsquad_ru_top2    tydiqa-goldp-v1.1-dev-russian     44.528302
# qa_mbert_extsquad_ru_top2                         xquad.ru     48.651001
# qa_mbert_extsquad_ru_top3    tydiqa-goldp-v1.1-dev-russian     41.509434
# qa_mbert_extsquad_ru_top3                         xquad.ru     43.777198
# qa_mbert_extsquad_ru_top5    tydiqa-goldp-v1.1-dev-russian     43.270440
# qa_mbert_extsquad_ru_top5                         xquad.ru     44.647520
# qa_mbert_extsquad5k_ru_top1  tydiqa-goldp-v1.1-dev-russian     33.459119
# qa_mbert_extsquad5k_ru_top1                       xquad.ru     38.207137
# qa_mbert_extsquad5k_ru_top2  tydiqa-goldp-v1.1-dev-russian     35.597484
# qa_mbert_extsquad5k_ru_top2                       xquad.ru     34.203655
# qa_mbert_extsquad5k_ru_top3  tydiqa-goldp-v1.1-dev-russian     34.465409
# qa_mbert_extsquad5k_ru_top3                       xquad.ru     34.464752
# qa_mbert_extsquad5k_ru_top5  tydiqa-goldp-v1.1-dev-russian     35.220126
# qa_mbert_extsquad5k_ru_top5                       xquad.ru     35.683203
#
#                              f1_scores
# ckpt_names
# qa_mbert_synthetic_ru_top1   25.675100
# qa_mbert_synthetic_ru_top1   18.252138
# qa_mbert_synthetic_ru_top2   29.901063
# qa_mbert_synthetic_ru_top2   20.470549
# qa_mbert_synthetic_ru_top3   29.134025
# qa_mbert_synthetic_ru_top3   22.054233
# qa_mbert_synthetic_ru_top5   27.896569
# qa_mbert_synthetic_ru_top5   20.895918
# qa_mbert_extsquad_ru_top1    64.690580
# qa_mbert_extsquad_ru_top1    65.566237
# qa_mbert_extsquad_ru_top2    61.695509
# qa_mbert_extsquad_ru_top2    63.519925
# qa_mbert_extsquad_ru_top3    59.700919
# qa_mbert_extsquad_ru_top3    57.932594
# qa_mbert_extsquad_ru_top5    60.059433
# qa_mbert_extsquad_ru_top5    59.518720
# qa_mbert_extsquad5k_ru_top1  50.319002
# qa_mbert_extsquad5k_ru_top1  51.537495
# qa_mbert_extsquad5k_ru_top2  52.133244
# qa_mbert_extsquad5k_ru_top2  47.863438
# qa_mbert_extsquad5k_ru_top3  50.630366
# qa_mbert_extsquad5k_ru_top3  47.698129
# qa_mbert_extsquad5k_ru_top5  52.209345
# qa_mbert_extsquad5k_ru_top5  49.023963

# %%
ckpt_names = ['qa_mbert_synthetic_hi_top1', 'qa_mbert_synthetic_hi_top2',
              'qa_mbert_synthetic_hi_top3', 'qa_mbert_synthetic_hi_top5',
              'qa_mbert_extsquad_hi_top1', 'qa_mbert_extsquad_hi_top2',
              'qa_mbert_extsquad_hi_top3', 'qa_mbert_extsquad_hi_top5',
              'qa_mbert_extsquad5k_hi_top1', 'qa_mbert_extsquad5k_hi_top2',
              'qa_mbert_extsquad5k_hi_top3', 'qa_mbert_extsquad5k_hi_top5']
group_metrics(ckpt_names)
# Out:
# Empty DataFrame
# Columns: [dataset_names, exact_scores, f1_scores]
# Index: []

# %%
ckpt_names = ['qa_mbert_synthetic_vi_top1', 'qa_mbert_synthetic_vi_top2',
              'qa_mbert_synthetic_vi_top3', 'qa_mbert_synthetic_vi_top5',
              'qa_mbert_extsquad_vi_top1', 'qa_mbert_extsquad_vi_top2',
              'qa_mbert_extsquad_vi_top3', 'qa_mbert_extsquad_vi_top5',
              'qa_mbert_extsquad5k_vi_top1', 'qa_mbert_extsquad5k_vi_top2',
              'qa_mbert_extsquad5k_vi_top3', 'qa_mbert_extsquad5k_vi_top5']
group_metrics(ckpt_names)
# Out:
#                                   dataset_names  exact_scores  f1_scores
# ckpt_names
# qa_mbert_synthetic_vi_top1   mlqa-v1-test-vi-vi      7.389675  13.234309
# qa_mbert_synthetic_vi_top1             xquad.vi     10.445205  16.669212
# qa_mbert_synthetic_vi_top2   mlqa-v1-test-vi-vi      9.179850  15.879419
# qa_mbert_synthetic_vi_top2             xquad.vi     12.585616  18.839686
# qa_mbert_synthetic_vi_top3   mlqa-v1-test-vi-vi     11.136553  18.756102
# qa_mbert_synthetic_vi_top3             xquad.vi     13.527397  21.251181
# qa_mbert_synthetic_vi_top5   mlqa-v1-test-vi-vi     10.366361  17.323405
# qa_mbert_synthetic_vi_top5             xquad.vi     12.414384  20.054625
# qa_mbert_extsquad_vi_top1    mlqa-v1-test-vi-vi     37.281432  54.398071
# qa_mbert_extsquad_vi_top1              xquad.vi     46.404110  63.988515
# qa_mbert_extsquad_vi_top2    mlqa-v1-test-vi-vi     36.823480  54.308942
# qa_mbert_extsquad_vi_top2              xquad.vi     46.147260  63.551280
# qa_mbert_extsquad_vi_top3    mlqa-v1-test-vi-vi     36.448793  53.925293
# qa_mbert_extsquad_vi_top3              xquad.vi     44.520548  61.760005
# qa_mbert_extsquad_vi_top5    mlqa-v1-test-vi-vi     30.953372  46.406455
# qa_mbert_extsquad_vi_top5              xquad.vi     38.013699  54.121480
# qa_mbert_extsquad5k_vi_top1  mlqa-v1-test-vi-vi     28.101582  43.350246
# qa_mbert_extsquad5k_vi_top1            xquad.vi     36.729452  52.812744
# qa_mbert_extsquad5k_vi_top2  mlqa-v1-test-vi-vi     26.436303  41.722057
# qa_mbert_extsquad5k_vi_top2            xquad.vi     34.760274  50.547600
# qa_mbert_extsquad5k_vi_top3  mlqa-v1-test-vi-vi     26.665279  41.167704
# qa_mbert_extsquad5k_vi_top3            xquad.vi     34.503425  50.412599
# qa_mbert_extsquad5k_vi_top5  mlqa-v1-test-vi-vi     25.853455  40.385079
# qa_mbert_extsquad5k_vi_top5            xquad.vi     32.619863  47.531592

# %%
ckpt_names = ['qa_mbert_synthetic_ja_top1', 'qa_mbert_synthetic_ja_top2',
              'qa_mbert_synthetic_ja_top3', 'qa_mbert_synthetic_ja_top5',
              'qa_mbert_extsquad_ja_top1', 'qa_mbert_extsquad_ja_top2',
              'qa_mbert_extsquad_ja_top3', 'qa_mbert_extsquad_ja_top5',
              'qa_mbert_extsquad5k_ja_top1', 'qa_mbert_extsquad5k_ja_top2',
              'qa_mbert_extsquad5k_ja_top3', 'qa_mbert_extsquad5k_ja_top5']
group_metrics(ckpt_names)
# Out:
#                             dataset_names  exact_scores  f1_scores
# ckpt_names
# qa_mbert_synthetic_ja_top1    dev-v1.1-ja     14.195584  15.614288
# qa_mbert_synthetic_ja_top2    dev-v1.1-ja     15.141956  16.048432
# qa_mbert_synthetic_ja_top3    dev-v1.1-ja     14.511041  15.532780
# qa_mbert_synthetic_ja_top5    dev-v1.1-ja     14.195584  16.577492
# qa_mbert_extsquad_ja_top1     dev-v1.1-ja     51.419558  52.234740
# qa_mbert_extsquad_ja_top2     dev-v1.1-ja     48.264984  49.746132
# qa_mbert_extsquad_ja_top3     dev-v1.1-ja     47.003155  48.080967
# qa_mbert_extsquad_ja_top5     dev-v1.1-ja     48.580442  49.600421
# qa_mbert_extsquad5k_ja_top1   dev-v1.1-ja     46.372240  47.862003
# qa_mbert_extsquad5k_ja_top2   dev-v1.1-ja     36.908517  38.035504
# qa_mbert_extsquad5k_ja_top3   dev-v1.1-ja     36.908517  37.619048
# qa_mbert_extsquad5k_ja_top5   dev-v1.1-ja     35.331230  36.873109

# %%
ckpt_names = ['qa_mbert_synthetic_all_top1', 'qa_mbert_synthetic_all_top2',
              'qa_mbert_synthetic_all_top3', 'qa_mbert_synthetic_all_top5',
              'qa_mbert_extsquad_all_top1', 'qa_mbert_extsquad_all_top2',
              'qa_mbert_extsquad_all_top3', 'qa_mbert_extsquad_all_top5',
              'qa_mbert_extsquad5k_all_top1', 'qa_mbert_extsquad5k_all_top2',
              'qa_mbert_extsquad5k_all_top3', 'qa_mbert_extsquad5k_all_top5']
group_metrics(ckpt_names)
# Out:
#                                               dataset_names  exact_scores  \
# ckpt_names
# qa_mbert_synthetic_all_top1                     dev-v1.1-es     20.748592
# qa_mbert_synthetic_all_top1                     dev-v1.1-ja     18.296530
# qa_mbert_synthetic_all_top1                        dev-v1.1     26.280221
# qa_mbert_synthetic_all_top1              mlqa-v1-test-es-es     16.512880
# qa_mbert_synthetic_all_top1              mlqa-v1-test-hi-hi     12.601326
# ...                                                     ...           ...
# qa_mbert_extsquad5k_all_top5  tydiqa-goldp-v1.1-dev-russian     33.081761
# qa_mbert_extsquad5k_all_top5                       xquad.es     39.863131
# qa_mbert_extsquad5k_all_top5                       xquad.hi     29.819820
# qa_mbert_extsquad5k_all_top5                       xquad.ru     35.596171
# qa_mbert_extsquad5k_all_top5                       xquad.vi     36.044521
#
#                               f1_scores
# ckpt_names
# qa_mbert_synthetic_all_top1   30.297740
# qa_mbert_synthetic_all_top1   18.804178
# qa_mbert_synthetic_all_top1   34.164148
# qa_mbert_synthetic_all_top1   28.633313
# qa_mbert_synthetic_all_top1   22.409264
# ...                                 ...
# qa_mbert_extsquad5k_all_top5  52.812081
# qa_mbert_extsquad5k_all_top5  54.956471
# qa_mbert_extsquad5k_all_top5  40.777961
# qa_mbert_extsquad5k_all_top5  49.524947
# qa_mbert_extsquad5k_all_top5  51.666218
#
# [144 rows x 3 columns]

# %%
def generate_table(columns, ckpts, df_key, metric_label, metric_name, table_part):
    text =  "\\begin{table}[ht]\n"
    text += "\\small\n"
    text += "\\centering\n"
    text += "\\addtolength{\\leftskip} {-2cm}"
    text += "\\addtolength{\\rightskip}{-2cm}"
    text += "\\renewcommand{\\arraystretch}{1.2}\n"
    
    n_columns = '|'.join([''.join(['l'] * len(x)) for _, x in columns.items()])
    text += "\\begin{tabular}{|l|%s|}\n" % n_columns
    
    text += "\\hline\n"
    text += "\\textbf{Trained on} $\\rightarrow$ &\n"
    
    column_headers = []
    for column_name, column_data in columns.items():
        column_headers += ["  \\multicolumn{%d}{c|}{\\textbf{%s}}" % (len(column_data), column_name)]
    text += " &\n".join(column_headers)
    text += "\\\\\n"
    text += "\\hline\n"
    text += "\\hline\n"
    
    text += "\\textbf{Tested on} $\\downarrow$ &\n"
    
    column_headers = []
    for _, column_data in columns.items():
        for _, subcol_data in column_data.items():
            column_headers += ["  \\multicolumn{1}{c|}{\\textbf{\\begin{tabular}[c]{@{}c@{}}%s\\end{tabular}}}" % (subcol_data['col_name'])]
    text += " &\n".join(column_headers)
    text += "\\\\\n"
    text += "\\hline\n"
    text += "\\hline\n"
    
    ## ROWS ##
    
    for ckpt_data in ckpts:
        text += "  \\textbf{\\begin{tabular}[c]{@{}l@{}}%s\\end{tabular}} &\n" % ckpt_data['row_name']
        
        if ckpt_data['for_all'] and not ckpt_data['multi_model_version']:
            df = group_metrics([ckpt_data['ckpts']['all']])

        row_scores = []
        for column_name, column_data in columns.items():
            for dataset_name, subcol_data in column_data.items():
                if ckpt_data['for_all']:
                    if ckpt_data['multi_model_version']:
                        multi_score = []
                        for k_top in [1, 2, 3, 5]:
                            if 'all' in ckpt_data['ckpts']:
                                k_ckpt_name = '%s%d' % (ckpt_data['ckpts']['all'], k_top)
                                df = group_metrics([k_ckpt_name])
                                item_score = df.loc[df['dataset_names'] == dataset_name][df_key].to_numpy()
                                item_score = ('%.4f' % item_score[0]) if len(item_score) > 0 else '-'
                            else:
                                item_score = '-'
                            multi_score += ["%s" % item_score]
                        multi_score = " \\\\".join(multi_score)
                        row_scores += ["\\begin{tabular}[c]{@{}l@{}}%s\\end{tabular}" % multi_score]
                    else:
                        item_score = df.loc[df['dataset_names'] == dataset_name][df_key].to_numpy()
                        item_score = ('%.4f' % item_score[0]) if len(item_score) > 0 else '-'
                        row_scores += ["%s" % item_score]
                else:
                    multi_score = []
                    for k_top in [1, 2, 3, 5]:
                        if column_name in ckpt_data['ckpts']:
                            k_ckpt_name = '%s%d' % (ckpt_data['ckpts'][column_name], k_top)
                            df = group_metrics([k_ckpt_name])
                            item_score = df.loc[df['dataset_names'] == dataset_name][df_key].to_numpy()
                            if len(item_score) == 0:
                                print(df.loc[df['dataset_names'] == dataset_name])
                                raise Exception()
                            item_score = ('%.4f' % item_score[0]) if len(item_score) > 0 else '-'
                        else:
                            item_score = '-'
                        multi_score += ["%s" % item_score]
                    multi_score = " \\\\".join(multi_score)
                    row_scores += ["\\begin{tabular}[c]{@{}l@{}}%s\\end{tabular}" % multi_score]
        text += " &\n".join(row_scores)
        text += "\\\\\n"
        text += "\\hline\n"
        if ckpt_data['insert_hline']:
            text += "\\hline \n"
    
    ## END TABLE ##
    
    text += "\\end{tabular}\n"
    text += "\\label{table:%sScoresModels%s}\n" % (metric_label, table_part)
    text += "\\caption{(Part %s of 2) %s of each model on each non-filtered synthetic dataset.}\n" % (table_part, metric_name)
    text += "\\end{table}\n"
    
    return text

# %%
ckpts = [
    {
        'ckpts': {'all': 'qa_mbert_squad'},
        'row_name': 'mBERT + SQuAD',
        'insert_hline': False,
        'multi_model_version': False,
        'for_all': True,
    },
    {
        'ckpts': {'all': 'qa_mbert_squad5k'},
        'row_name': 'mBERT + SQuAD-5k',
        'insert_hline': False,
        'multi_model_version': False,
        'for_all': True,
    },
    {
        'ckpts': {'all': 'qa_xlm_squad'},
        'row_name': 'XLM-R + SQuAD',
        'insert_hline': False,
        'multi_model_version': False,
        'for_all': True,
    },
    {
        'ckpts': {'all': 'qa_xlm_squad5k'},
        'row_name': 'XLM-R + SQuAD-5k',
        'insert_hline': True,
        'multi_model_version': False,
        'for_all': True,
    },
    ################
    {
        'ckpts': {
            'Spanish': 'qa_mbert_synthetic_es_top',
            'Russian': 'qa_mbert_synthetic_ru_top',
            'Vietnamese': 'qa_mbert_synthetic_vi_top',
            'Japanese': 'qa_mbert_synthetic_ja_top',
        },
        'row_name': 'mBERT +\\\\Synth\\_*',
        'insert_hline': False,
        'multi_model_version': True,
        'for_all': False,
    },
    {
        'ckpts': {
            'Spanish': 'qa_mbert_extsquad_es_top',
            'Russian': 'qa_mbert_extsquad_ru_top',
            'Vietnamese': 'qa_mbert_extsquad_vi_top',
            'Japanese': 'qa_mbert_extsquad_ja_top',
        },
        'row_name': 'mBERT + SQuAD +\\\\Synth\\_*',
        'insert_hline': False,
        'multi_model_version': True,
        'for_all': False,
    },
    {
        'ckpts': {
            'Spanish': 'qa_mbert_extsquad5k_es_top',
            'Russian': 'qa_mbert_extsquad5k_ru_top',
            'Vietnamese': 'qa_mbert_extsquad5k_vi_top',
            'Japanese': 'qa_mbert_extsquad5k_ja_top',
        },
        'row_name': 'mBERT + SQuAD-5k +\\\\Synth\\_*',
        'insert_hline': True,
        'multi_model_version': True,
        'for_all': False,
    },
    ################
    {
        'ckpts': {'all': 'qa_mbert_synthetic_all_top'},
        'row_name': 'mBERT +\\\\all Synth\\_*',
        'insert_hline': False,
        'multi_model_version': True,
        'for_all': True,
    },
    {
        'ckpts': {'all': 'qa_mbert_extsquad_all_top'},
        'row_name': 'mBERT + SQuAD +\\\\all Synth\\_*',
        'insert_hline': False,
        'multi_model_version': True,
        'for_all': True,
    },
    {
        'ckpts': {'all': 'qa_mbert_extsquad5k_all_top'},
        'row_name': 'mBERT + SQuAD-5k +\\\\all Synth\\_*',
        'insert_hline': True,
        'multi_model_version': True,
        'for_all': True,
    },
]

# %%
columns = {
    'Spanish': {
        'mlqa-v1-test-es-es': {
            'col_name': 'MLQA\\\\(es-es)',
        },
        'xquad.es': {
            'col_name': 'XQuAD\\\\(es)',
        },
        'dev-v1.1-es': {
            'col_name': 'Carrino et al.\\\\(SQuAD-es)',
        },
    },
    'Russian': {
        'tydiqa-goldp-v1.1-dev-russian': {
            'col_name': 'TyDiQA\\\\(ru)',
        },
        'xquad.ru': {
            'col_name': 'XQuAD\\\\(tu)',
        },
    },
}

metric_label = 'F1Scores'
metric_name = 'F1-Scores'
df_key = 'f1_scores'
table_part = '1'

table_1 = generate_table(columns, ckpts, df_key, metric_label, metric_name, table_part)

# %%
columns = {
    'Hindi': {
        'mlqa-v1-test-hi-hi': {
            'col_name': 'MLQA\\\\(hi-hi)',
        },
        'xquad.hi': {
            'col_name': 'XQuAD\\\\(hi)',
        },
    },
    'Vietnamese': {
        'mlqa-v1-test-vi-vi': {
            'col_name': 'MLQA\\\\(vi-vi)',
        },
        'xquad.vi': {
            'col_name': 'XQuAD\\\\(vi)',
        },
    },
    'Japanese': {
        'dev-v1.1-ja': {
            'col_name': 'Akari Asai et al.\\\\(SQuAD-ja)',
        },
    },
}

metric_label = 'F1Scores'
metric_name = 'F1-Scores'
df_key = 'f1_scores'
table_part = '2'

table_2 = generate_table(columns, ckpts, df_key, metric_label, metric_name, table_part)

# %%
columns = {
    'Spanish': {
        'mlqa-v1-test-es-es': {
            'col_name': 'MLQA\\\\(es-es)',
        },
        'xquad.es': {
            'col_name': 'XQuAD\\\\(es)',
        },
        'dev-v1.1-es': {
            'col_name': 'Carrino et al.\\\\(SQuAD-es)',
        },
    },
    'Russian': {
        'tydiqa-goldp-v1.1-dev-russian': {
            'col_name': 'TyDiQA\\\\(ru)',
        },
        'xquad.ru': {
            'col_name': 'XQuAD\\\\(tu)',
        },
    },
}

metric_label = 'ExactMatch'
metric_name = 'Exact-Match scores'
df_key = 'exact_scores'
table_part = '1'

table_3 = generate_table(columns, ckpts, df_key, metric_label, metric_name, table_part)

# %%
columns = {
    'Hindi': {
        'mlqa-v1-test-hi-hi': {
            'col_name': 'MLQA\\\\(hi-hi)',
        },
        'xquad.hi': {
            'col_name': 'XQuAD\\\\(hi)',
        },
    },
    'Vietnamese': {
        'mlqa-v1-test-vi-vi': {
            'col_name': 'MLQA\\\\(vi-vi)',
        },
        'xquad.vi': {
            'col_name': 'XQuAD\\\\(vi)',
        },
    },
    'Japanese': {
        'dev-v1.1-ja': {
            'col_name': 'Akari Asai et al.\\\\(SQuAD-ja)',
        },
    },
}

metric_label = 'ExactMatch'
metric_name = 'Exact-Match scores'
df_key = 'exact_scores'
table_part = '2'

table_4 = generate_table(columns, ckpts, df_key, metric_label, metric_name, table_part)

# %%
print(table_1)
print(table_2)
print(table_3)
print(table_4)
# Out:
# \begin{table}[ht]
# \small
# \centering
# \addtolength{\leftskip} {-2cm}\addtolength{\rightskip}{-2cm}\renewcommand{\arraystretch}{1.2}
# \begin{tabular}{|l|lll|ll|}
# \hline
# \textbf{Trained on} $\rightarrow$ &
#   \multicolumn{3}{c|}{\textbf{Spanish}} &
#   \multicolumn{2}{c|}{\textbf{Russian}}\\
# \hline
# \hline
# \textbf{Tested on} $\downarrow$ &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(es-es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}Carrino et al.\\(SQuAD-es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}TyDiQA\\(ru)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(tu)\end{tabular}}}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD\end{tabular}} &
# 62.8497 &
# 73.2986 &
# 68.6989 &
# 64.7889 &
# 68.7534\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k\end{tabular}} &
# 50.5748 &
# 59.8805 &
# 58.8240 &
# 55.6726 &
# 56.2824\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD\end{tabular}} &
# 53.5784 &
# 64.4413 &
# 61.4471 &
# 46.3373 &
# 62.5871\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD-5k\end{tabular}} &
# 46.9428 &
# 57.8294 &
# 55.5428 &
# 45.1194 &
# 54.6547\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}20.6131 \\21.8113 \\25.9840 \\24.4752\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}22.0408 \\23.0928 \\27.3085 \\24.3163\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}21.7960 \\23.9937 \\27.7269 \\25.4061\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}25.6751 \\29.9011 \\29.1340 \\27.8966\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}18.2521 \\20.4705 \\22.0542 \\20.8959\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}60.0252 \\58.3854 \\57.3415 \\57.3771\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}69.4846 \\69.4461 \\67.0527 \\67.0041\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}65.8149 \\65.5317 \\64.8634 \\63.7026\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}64.6906 \\61.6955 \\59.7009 \\60.0594\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}65.5662 \\63.5199 \\57.9326 \\59.5187\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}47.4263 \\44.8666 \\45.5134 \\45.7594\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}56.9147 \\53.8381 \\53.2688 \\54.1170\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}55.6777 \\53.1641 \\53.5567 \\53.1757\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}50.3190 \\52.1332 \\50.6304 \\52.2093\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}51.5375 \\47.8634 \\47.6981 \\49.0240\end{tabular}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}28.6333 \\27.9557 \\29.3364 \\27.5457\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}29.0928 \\28.4582 \\28.6619 \\28.4869\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}30.2977 \\29.5789 \\30.0152 \\28.4139\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}35.7380 \\39.3758 \\38.8025 \\36.3265\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}25.6967 \\25.7774 \\27.3074 \\25.2122\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}59.1779 \\58.9231 \\57.0973 \\54.9453\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}69.7263 \\68.5909 \\66.1823 \\64.3443\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}65.8503 \\65.7938 \\63.5919 \\61.9457\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}61.1703 \\59.5012 \\60.3344 \\60.1614\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}63.9481 \\61.5481 \\58.5860 \\59.9108\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}45.9204 \\46.5897 \\46.1557 \\46.4989\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}55.4792 \\55.4617 \\54.9207 \\54.9565\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}53.2713 \\53.9264 \\53.3209 \\52.8947\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.4817 \\52.4537 \\52.9575 \\52.8121\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}48.6364 \\48.9965 \\49.5059 \\49.5249\end{tabular}\\
# \hline
# \hline
# \end{tabular}
# \label{table:F1ScoresScoresModels1}
# \caption{(Part 1 of 2) F1-Scores of each model on each non-filtered synthetic dataset.}
# \end{table}
#
# \begin{table}[ht]
# \small
# \centering
# \addtolength{\leftskip} {-2cm}\addtolength{\rightskip}{-2cm}\renewcommand{\arraystretch}{1.2}
# \begin{tabular}{|l|ll|ll|l|}
# \hline
# \textbf{Trained on} $\rightarrow$ &
#   \multicolumn{2}{c|}{\textbf{Hindi}} &
#   \multicolumn{2}{c|}{\textbf{Vietnamese}} &
#   \multicolumn{1}{c|}{\textbf{Japanese}}\\
# \hline
# \hline
# \textbf{Tested on} $\downarrow$ &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(hi-hi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(hi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(vi-vi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(vi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}Akari Asai et al.\\(SQuAD-ja)\end{tabular}}}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD\end{tabular}} &
# 45.9986 &
# 54.9331 &
# 58.5264 &
# 67.2803 &
# 63.4122\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k\end{tabular}} &
# 36.3982 &
# 43.2033 &
# 45.7508 &
# 53.4093 &
# 49.5760\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD\end{tabular}} &
# 47.8085 &
# 56.5156 &
# 55.2357 &
# 62.4446 &
# 55.1421\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD-5k\end{tabular}} &
# 35.2538 &
# 47.2715 &
# 44.4292 &
# 55.4163 &
# 48.2305\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}13.2343 \\15.8794 \\18.7561 \\17.3234\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}16.6692 \\18.8397 \\21.2512 \\20.0546\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}15.6143 \\16.0484 \\15.5328 \\16.5775\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}54.3981 \\54.3089 \\53.9253 \\46.4065\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}63.9885 \\63.5513 \\61.7600 \\54.1215\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.2347 \\49.7461 \\48.0810 \\49.6004\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}43.3502 \\41.7221 \\41.1677 \\40.3851\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.8127 \\50.5476 \\50.4126 \\47.5316\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}47.8620 \\38.0355 \\37.6190 \\36.8731\end{tabular}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}22.4093 \\21.3525 \\23.0497 \\21.3823\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}23.5924 \\22.1867 \\24.9157 \\22.8927\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}10.3790 \\8.3085 \\8.6654 \\8.2938\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}8.6019 \\6.4268 \\6.9589 \\6.7222\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}18.8042 \\19.9211 \\19.2079 \\17.7703\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}40.2340 \\40.7589 \\38.5001 \\38.3495\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}47.1854 \\49.6326 \\48.6265 \\47.9149\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}51.8912 \\52.4172 \\50.4856 \\50.3543\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}61.2665 \\61.7615 \\58.6477 \\58.3267\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.7024 \\51.6471 \\45.9569 \\48.3807\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}33.1176 \\33.3429 \\31.1583 \\34.0040\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}40.0968 \\41.5585 \\39.3123 \\40.7780\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}41.2950 \\42.3750 \\40.9491 \\42.9551\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}50.7042 \\50.6807 \\49.4208 \\51.6662\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}41.5837 \\42.4395 \\34.7607 \\41.7201\end{tabular}\\
# \hline
# \hline
# \end{tabular}
# \label{table:F1ScoresScoresModels2}
# \caption{(Part 2 of 2) F1-Scores of each model on each non-filtered synthetic dataset.}
# \end{table}
#
# \begin{table}[ht]
# \small
# \centering
# \addtolength{\leftskip} {-2cm}\addtolength{\rightskip}{-2cm}\renewcommand{\arraystretch}{1.2}
# \begin{tabular}{|l|lll|ll|}
# \hline
# \textbf{Trained on} $\rightarrow$ &
#   \multicolumn{3}{c|}{\textbf{Spanish}} &
#   \multicolumn{2}{c|}{\textbf{Russian}}\\
# \hline
# \hline
# \textbf{Tested on} $\downarrow$ &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(es-es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}Carrino et al.\\(SQuAD-es)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}TyDiQA\\(ru)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(tu)\end{tabular}}}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD\end{tabular}} &
# 42.3683 &
# 55.0898 &
# 49.9952 &
# 47.0440 &
# 51.5231\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k\end{tabular}} &
# 32.4491 &
# 42.6005 &
# 41.3635 &
# 38.7421 &
# 39.5126\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD\end{tabular}} &
# 36.1154 &
# 49.7861 &
# 45.2920 &
# 31.2030 &
# 48.0587\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD-5k\end{tabular}} &
# 29.4615 &
# 42.0873 &
# 38.9160 &
# 28.9474 &
# 38.5677\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}12.3606 \\13.2641 \\15.1865 \\14.3214\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}14.3713 \\15.9110 \\17.3653 \\16.1677\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}14.7427 \\16.4900 \\18.8867 \\17.6931\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}15.7233 \\16.9811 \\16.8553 \\18.1132\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}12.6197 \\14.7084 \\15.1436 \\14.4473\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}40.5805 \\39.0042 \\37.9854 \\38.0431\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}53.5500 \\52.9512 \\50.8982 \\51.3259\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}49.6706 \\49.8043 \\49.0595 \\48.0283\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}47.1698 \\44.5283 \\41.5094 \\43.2704\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}49.2602 \\48.6510 \\43.7772 \\44.6475\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}30.2960 \\28.6044 \\28.7774 \\29.5463\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}40.8041 \\38.5800 \\36.2703 \\38.2378\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}40.4564 \\38.3080 \\38.3367 \\38.5372\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}33.4591 \\35.5975 \\34.4654 \\35.2201\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}38.2071 \\34.2037 \\34.4648 \\35.6832\end{tabular}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}16.5129 \\16.4168 \\16.8781 \\16.3975\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}19.1617 \\18.1352 \\18.1352 \\18.4773\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}20.7486 \\20.3476 \\20.2330 \\19.7556\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}22.5157 \\24.6541 \\23.0189 \\23.7736\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}17.0583 \\17.3194 \\17.3194 \\16.9713\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}39.9846 \\39.8116 \\38.8889 \\36.6590\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.6091 \\51.0693 \\50.2994 \\48.3319\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}49.7183 \\50.2339 \\48.2670 \\46.7106\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}43.5220 \\40.5031 \\42.8931 \\42.2642\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}48.0418 \\46.1271 \\42.9939 \\43.7772\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}29.0081 \\29.7962 \\29.7001 \\29.9308\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}39.6920 \\39.5210 \\38.7511 \\39.8631\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}38.5754 \\38.8618 \\38.4990 \\38.0311\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}34.8428 \\33.4591 \\35.2201 \\33.0818\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}34.9869 \\34.7258 \\35.1610 \\35.5962\end{tabular}\\
# \hline
# \hline
# \end{tabular}
# \label{table:ExactMatchScoresModels1}
# \caption{(Part 1 of 2) Exact-Match scores of each model on each non-filtered synthetic dataset.}
# \end{table}
#
# \begin{table}[ht]
# \small
# \centering
# \addtolength{\leftskip} {-2cm}\addtolength{\rightskip}{-2cm}\renewcommand{\arraystretch}{1.2}
# \begin{tabular}{|l|ll|ll|l|}
# \hline
# \textbf{Trained on} $\rightarrow$ &
#   \multicolumn{2}{c|}{\textbf{Hindi}} &
#   \multicolumn{2}{c|}{\textbf{Vietnamese}} &
#   \multicolumn{1}{c|}{\textbf{Japanese}}\\
# \hline
# \hline
# \textbf{Tested on} $\downarrow$ &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(hi-hi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(hi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}MLQA\\(vi-vi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}XQuAD\\(vi)\end{tabular}}} &
#   \multicolumn{1}{c|}{\textbf{\begin{tabular}[c]{@{}c@{}}Akari Asai et al.\\(SQuAD-ja)\end{tabular}}}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD\end{tabular}} &
# 31.9823 &
# 41.2613 &
# 39.6336 &
# 48.4589 &
# 61.5142\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k\end{tabular}} &
# 23.3358 &
# 30.2703 &
# 28.8926 &
# 36.7295 &
# 47.3186\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD\end{tabular}} &
# 33.8000 &
# 43.7931 &
# 38.6326 &
# 45.6336 &
# 53.8226\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}XLM-R + SQuAD-5k\end{tabular}} &
# 22.5785 &
# 33.8793 &
# 28.4913 &
# 39.8116 &
# 46.7890\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}7.3897 \\9.1799 \\11.1366 \\10.3664\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}10.4452 \\12.5856 \\13.5274 \\12.4144\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}14.1956 \\15.1420 \\14.5110 \\14.1956\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}37.2814 \\36.8235 \\36.4488 \\30.9534\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}46.4041 \\46.1473 \\44.5205 \\38.0137\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}51.4196 \\48.2650 \\47.0032 \\48.5804\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}- \\- \\- \\-\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}28.1016 \\26.4363 \\26.6653 \\25.8535\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}36.7295 \\34.7603 \\34.5034 \\32.6199\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}46.3722 \\36.9085 \\36.9085 \\35.3312\end{tabular}\\
# \hline
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}12.6013 \\12.8470 \\13.4365 \\12.5768\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}14.0541 \\13.9640 \\15.9459 \\14.4144\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}3.7677 \\3.2057 \\2.8310 \\3.0183\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}2.8253 \\2.3973 \\1.7979 \\1.7123\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}18.2965 \\18.9274 \\18.6120 \\17.0347\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}27.8310 \\28.6170 \\26.4800 \\26.1115\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}35.9459 \\37.2973 \\37.0270 \\35.3153\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}35.0749 \\35.0333 \\33.4513 \\33.2431\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}42.8938 \\44.6918 \\41.0103 \\41.3527\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}52.0505 \\50.4732 \\44.7950 \\47.0032\end{tabular}\\
# \hline
#   \textbf{\begin{tabular}[c]{@{}l@{}}mBERT + SQuAD-5k +\\all Synth\_*\end{tabular}} &
# \begin{tabular}[c]{@{}l@{}}22.0093 \\22.3041 \\20.8303 \\22.4515\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}28.8288 \\29.8198 \\28.5586 \\29.8198\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}26.4571 \\27.3522 \\25.7077 \\27.8310\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}34.9315 \\33.9897 \\33.9897 \\36.0445\end{tabular} &
# \begin{tabular}[c]{@{}l@{}}39.4322 \\41.0095 \\33.1230 \\40.6940\end{tabular}\\
# \hline
# \hline
# \end{tabular}
# \label{table:ExactMatchScoresModels2}
# \caption{(Part 2 of 2) Exact-Match scores of each model on each non-filtered synthetic dataset.}
# \end{table}
